# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')
from matplotlib.pyplot import figure
matplotlib.rcParams['figure.figsize'] = (12, 8)
# %matplotlib inline

# %% [markdown]
# **Tracks Dataset**

# %%
tracks_df = pd.read_csv("/content/tracks.csv")

# %%
tracks_df.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
# Check for null values
pd.isnull(tracks_df).sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
tracks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
sorted_df = tracks_df.sort_values('popularity', ascending = True).head(10)
sorted_df
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %%
tracks_df.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
tracks_df.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %%
popular_tracks = tracks_df[(tracks_df['popularity'] > 90)]
popular_tracks.sort_values('popularity', ascending = False)
# Out:
#                            id  \
# 93802  4iJyoBOLtHqaGxP12qzhQI
# 93803  7lPN2DXiMsVn7XUKtOW1CS
# 93804  3Ofmpyhv5UAQ70mENzB277
# 92810  5QO79kh1waicV47BqGRL3g
# 92811  6tDDoYIxWvMLTdKpjFkc1B
# 92813  0VjIjW4GlUZAMYd2vXMi3b
# 93805  7MAibcTli4IisCtbHKrGMh
# 92814  6f3Slt0GbA2bPZlz0aIFXN
# 91866  60ynsPSSKe6O3sfwRnIBRf
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp
# 92817  27OeeYzk6klgBh83TSvGMA
# 92819  1xK1Gg9SxG8fy2Ya373oqb
# 93807  4cG7HUWYHBV6R6tHn1gxrl
# 93806  7Bk0uXKk1uPT0XuQbpFzvs
# 92821  2XIc1pqjXV3Cr2BQUGNBck
# 92823  3YJJjQPAbDT7mGpX3WtQ9A
# 93812  3iw6V4LH7yPj1ESORX9RIN
# 93810  5uEYRdEIh9Bo4fpjDd4Na9
# 93811  4u4NyuceXP7Uzh7XFJKCr1
# 92829  6ft4hAq6yde8jPZY2i5zLr
# 91867  6UelLqGlWMcVH1E5c4H7lY
# 93809  1XXimziG1uhM0eDNCZCrUl
# 92827  3VvA1wSxukMLsvXoXtlwWx
# 92826  35mvY5S1H3J2QZyna3TFe0
# 92824  47EiUVwUp4C9fGccaPuUCS
# 93808  5YYW3yRktprLRr47WK219Y
# 93813  2TksvaRivgAEj780DgRB73
# 93814  5YaskwnGDZFDRipaqzbwQx
# 93815  3aQem4jVGdhtg116TmJnHz
# 92835  6Im9k8u9iIzKMrmV7BWtlF
# ...

# %%
tracks_df.set_index("release_date", inplace = True)
tracks_df.index = pd.to_datetime(tracks_df.index)
tracks_df.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922-01-01             0       163080         0      ['Dick Haymes']
#
# ...

# %%
tracks_df[["artists"]].iloc[18]
# Out:
# artists    ['Victor Boucher']
# Name: 1922-01-01 00:00:00, dtype: object

# %%
tracks_df["duration"] = tracks_df["duration_ms"].apply(lambda x: round(x/1000))
tracks_df.drop("duration_ms", inplace = True, axis = 1)

# %%
tracks_df.duration.head()
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-01-01    163
# Name: duration, dtype: int64

# %%
correlation_matrix = tracks_df.drop(["key", "mode", "explicit"], axis = 1).corr(method = "pearson")
sb.heatmap(correlation_matrix, annot = True)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# <ipython-input-17-3663a564b4c3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = tracks_df.drop(["key", "mode", "explicit"], axis = 1).corr(method = "pearson")

# %%
sample_df = tracks_df.sample(int(0.004*len(tracks_df)))

# %%
print(len(sample_df))
# Out:
# 2346

# %%
sb.regplot(x = "energy", y = "loudness", data = sample_df, scatter_kws = {'color' : 'red'}, line_kws = {'color' : 'blue'})
plt.title("Loudness vs Energy Correlation")
plt.xlabel("energy")
plt.ylabel("loudness")
plt.show()

# %%
sb.regplot(x = "acousticness", y = "popularity", data = sample_df, scatter_kws = {'color' : 'red'}, line_kws = {'color' : 'blue'})
plt.title("Popularity vs Acousticness Correlation")
plt.xlabel("Acousticness")
plt.ylabel("Popularity")
plt.show()

# %%
tracks_df['dates'] = tracks_df.index.get_level_values('release_date')
tracks_df.dates = pd.to_datetime(tracks_df.dates)
years = tracks_df.dates.dt.year

# %%
sb.displot(years, discrete = True, aspect = 2, height = 5, kind = "hist").set(title = "Number of songs per year")

# %%
total_duration = tracks_df.duration
sb.barplot(x = years, y = total_duration)
plt.title("Year vs Duration")
plt.xlabel("year")
plt.ylabel("Duration")
plt.xticks(rotation=90)
plt.show()

# %%
sb.lineplot(x = years, y = total_duration)
plt.title("Year Vs Duration")
plt.xlabel("Year")
plt.ylabel("Duration")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Features**

# %%
features_df = pd.read_csv("/content/SpotifyFeatures.csv")
features_df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
sb.color_palette("rocket", as_cmap = True)
sb.barplot(y = 'genre', x = 'duration_ms', data = features_df)
plt.xlabel("Duration in milliseconds")
plt.ylabel("Genres")
plt.title("Duration of Songs in different Genres")
# Out:
# Text(0.5, 1.0, 'Duration of Songs in different Genres')

# %%
 sb.set_style(style = "darkgrid")
 famous = features_df.sort_values("popularity", ascending = False).head(10)
 sb.barplot(y = 'genre', x = 'popularity', data = famous)
 plt.title("Top 5 popular genres")
 plt.xlabel("Popularity")
 plt.ylabel("Genres")
 plt.show()
